# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %% [markdown]
# ### Data Processing

# %%
df = pd.read_csv("New York Solar1.csv") 
df
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 0      2019      1    1     0       0    0             0           8
# 1      2019      1    1     1       0    0             0           7
# 2      2019      1    1     2       0    0             0           6
# 3      2019      1    1     3       0    0             0           6
# 4      2019      1    1     4       0    0             0           6
# ...     ...    ...  ...   ...     ...  ...           ...         ...
# 26299  2021     12   31    19       0   39           318           8
# 26300  2021     12   31    20       0   28           197           8
# 26301  2021     12   31    21       0   21            62           7
# 26302  2021     12   31    22       0    0             0           7
# 26303  2021     12   31    23       0    0             0           7
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  GHI_DAY_AHEAD
# 0             4.6              95.61          5.9      1017              0
# 1             4.9              95.70          6.4      1015              0
# 2             4.3              96.75          6.7      1013              0
# 3             4.1              97.53          7.1      1011              0
# 4             3.9              98.02          7.7      1008              0
# ...           ...                ...          ...       ...            ...
# 26299         1.6              92.28         10.4      1012            207
# 26300         1.4              95.16         10.0      1012             96
# 26301         1.3              97.93          9.3      1012             38
# 26302         1.3              99.08          9.0      1012              0
# 26303         1.2              99.45          8.9      1012              0
#
# [26304 rows x 13 columns]

# %%
df = df.dropna()
df
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 0      2019      1    1     0       0    0             0           8
# 1      2019      1    1     1       0    0             0           7
# 2      2019      1    1     2       0    0             0           6
# 3      2019      1    1     3       0    0             0           6
# 4      2019      1    1     4       0    0             0           6
# ...     ...    ...  ...   ...     ...  ...           ...         ...
# 26299  2021     12   31    19       0   39           318           8
# 26300  2021     12   31    20       0   28           197           8
# 26301  2021     12   31    21       0   21            62           7
# 26302  2021     12   31    22       0    0             0           7
# 26303  2021     12   31    23       0    0             0           7
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  GHI_DAY_AHEAD
# 0             4.6              95.61          5.9      1017              0
# 1             4.9              95.70          6.4      1015              0
# 2             4.3              96.75          6.7      1013              0
# 3             4.1              97.53          7.1      1011              0
# 4             3.9              98.02          7.7      1008              0
# ...           ...                ...          ...       ...            ...
# 26299         1.6              92.28         10.4      1012            207
# 26300         1.4              95.16         10.0      1012             96
# 26301         1.3              97.93          9.3      1012             38
# 26302         1.3              99.08          9.0      1012              0
# 26303         1.2              99.45          8.9      1012              0
#
# [26304 rows x 13 columns]

# %%
NewYorkdf = pd.read_csv("New York Solar1.csv") 
NewYorkdf
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 0      2019      1    1     0       0    0             0           8
# 1      2019      1    1     1       0    0             0           7
# 2      2019      1    1     2       0    0             0           6
# 3      2019      1    1     3       0    0             0           6
# 4      2019      1    1     4       0    0             0           6
# ...     ...    ...  ...   ...     ...  ...           ...         ...
# 26299  2021     12   31    19       0   39           318           8
# 26300  2021     12   31    20       0   28           197           8
# 26301  2021     12   31    21       0   21            62           7
# 26302  2021     12   31    22       0    0             0           7
# 26303  2021     12   31    23       0    0             0           7
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  GHI_DAY_AHEAD
# 0             4.6              95.61          5.9      1017              0
# 1             4.9              95.70          6.4      1015              0
# 2             4.3              96.75          6.7      1013              0
# 3             4.1              97.53          7.1      1011              0
# 4             3.9              98.02          7.7      1008              0
# ...           ...                ...          ...       ...            ...
# 26299         1.6              92.28         10.4      1012            207
# 26300         1.4              95.16         10.0      1012             96
# 26301         1.3              97.93          9.3      1012             38
# 26302         1.3              99.08          9.0      1012              0
# 26303         1.2              99.45          8.9      1012              0
#
# [26304 rows x 13 columns]

# %%
NewYorkdf = NewYorkdf.dropna()
NewYorkdf
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 0      2019      1    1     0       0    0             0           8
# 1      2019      1    1     1       0    0             0           7
# 2      2019      1    1     2       0    0             0           6
# 3      2019      1    1     3       0    0             0           6
# 4      2019      1    1     4       0    0             0           6
# ...     ...    ...  ...   ...     ...  ...           ...         ...
# 26299  2021     12   31    19       0   39           318           8
# 26300  2021     12   31    20       0   28           197           8
# 26301  2021     12   31    21       0   21            62           7
# 26302  2021     12   31    22       0    0             0           7
# 26303  2021     12   31    23       0    0             0           7
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  GHI_DAY_AHEAD
# 0             4.6              95.61          5.9      1017              0
# 1             4.9              95.70          6.4      1015              0
# 2             4.3              96.75          6.7      1013              0
# 3             4.1              97.53          7.1      1011              0
# 4             3.9              98.02          7.7      1008              0
# ...           ...                ...          ...       ...            ...
# 26299         1.6              92.28         10.4      1012            207
# 26300         1.4              95.16         10.0      1012             96
# 26301         1.3              97.93          9.3      1012             38
# 26302         1.3              99.08          9.0      1012              0
# 26303         1.2              99.45          8.9      1012              0
#
# [26304 rows x 13 columns]

# %% [markdown]
# ### Correlatino betweeen GHI and other features

# %%
NewYorkdf_new = NewYorkdf.copy()
NewYorkdf_new['DateTime'] = NewYorkdf[['Year', 'Month', 'Day', 'Hour']].apply(lambda s : datetime.datetime(*s),axis = 1)
NewYorkdf_new = NewYorkdf_new.drop(columns = ['Year','Minute'])
NewYorkdf_new['DateTime'] = pd.to_datetime(NewYorkdf_new['DateTime']) 
NewYorkdf_new.set_index(['DateTime'], drop=True, inplace=True)
NewYorkdf_new.head(15)
# Out:
#                      Month  Day  Hour  GHI  Clearsky GHI  Cloud Type  \
# DateTime
# 2019-01-01 00:00:00      1    1     0    0             0           8
# 2019-01-01 01:00:00      1    1     1    0             0           7
# 2019-01-01 02:00:00      1    1     2    0             0           6
# 2019-01-01 03:00:00      1    1     3    0             0           6
# 2019-01-01 04:00:00      1    1     4    0             0           6
# 2019-01-01 05:00:00      1    1     5    0             0           6
# 2019-01-01 06:00:00      1    1     6    0             0           6
# 2019-01-01 07:00:00      1    1     7    0             0           6
# 2019-01-01 08:00:00      1    1     8    0             0           8
# 2019-01-01 09:00:00      1    1     9    0             0           7
# 2019-01-01 10:00:00      1    1    10    0             0           8
# 2019-01-01 11:00:00      1    1    11    0             0           7
# 2019-01-01 12:00:00      1    1    12    0             0           7
# 2019-01-01 13:00:00      1    1    13   34            70           7
# 2019-01-01 14:00:00      1    1    14   67           214           6
#
#                      Wind Speed  Relative Humidity  Temperature  Pressure  \
# DateTime
# 2019-01-01 00:00:00         4.6              95.61          5.9      1017
# 2019-01-01 01:00:00         4.9              95.70          6.4      1015
# 2019-01-01 02:00:00         4.3              96.75          6.7      1013
# 2019-01-01 03:00:00         4.1              97.53          7.1      1011
# 2019-01-01 04:00:00         3.9              98.02          7.7      1008
# 2019-01-01 05:00:00         4.4              97.35          8.3      1006
# 2019-01-01 06:00:00         4.7              97.22          9.0      1005
# 2019-01-01 07:00:00         4.9              97.46          9.9      1003
# 2019-01-01 08:00:00         4.5              98.52         10.3      1002
# 2019-01-01 09:00:00         4.5              98.36         10.9      1001
# 2019-01-01 10:00:00         4.9              97.35         12.0      1001
# 2019-01-01 11:00:00         4.8              97.49         12.4      1002
# 2019-01-01 12:00:00         4.7              95.42         12.6      1003
# 2019-01-01 13:00:00         4.8              90.58         12.5      1005
# 2019-01-01 14:00:00         4.7              85.68         12.0      1006
#
#                      GHI_DAY_AHEAD
# DateTime
# 2019-01-01 00:00:00              0
# 2019-01-01 01:00:00              0
# 2019-01-01 02:00:00              0
# 2019-01-01 03:00:00              0
# 2019-01-01 04:00:00              0
# 2019-01-01 05:00:00              0
# 2019-01-01 06:00:00              0
# 2019-01-01 07:00:00              0
# 2019-01-01 08:00:00              0
# 2019-01-01 09:00:00              0
# 2019-01-01 10:00:00              0
# 2019-01-01 11:00:00              0
# 2019-01-01 12:00:00              0
# 2019-01-01 13:00:00             40
# 2019-01-01 14:00:00            125

# %% [markdown]
# ## Model training and testing

# %% [markdown]
# #### Split dataset into training and testing set

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

# Features
X = NewYorkdf.copy()
X = X.drop(columns = ['GHI'])
X.index = NewYorkdf_new.index

# GHI
y = NewYorkdf_new['GHI']

X_train, X_test, Y_train, Y_test = X[:17544],X[17544:], y[:17544], y[17544:]

# %% [markdown]
# #### Grid Search to optain the best parameters

# %%
param_grid = {
    'max_depth': [5, 7, 9, 11, 15, 50],
    'n_estimators': [60, 80, 100 , 120, 140, 160, 180, 200, 220] }

# Create Randfom forest model
rf = RandomForestRegressor()

# Grid search of parameters, using 3 fold cross validation, 
# search across different combinations, and use all available cores
RF_model = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)
# fit model 
# %time RF_model.fit(X_train,Y_train)

print(RF_model.best_params_)

# Make Prediction 
y_pred = RF_model.predict(X_test)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# CPU times: total: 7.08 s
# Wall time: 5min 31s
# {'max_depth': 11, 'n_estimators': 220}

# %% [markdown]
# #### Comparision between Actual and Train predictions - Random Forest

# %%
train_predictions = RF_model.predict(X_train).flatten()
train_results = pd.DataFrame(data = {'Train prediction':train_predictions,'Actual':Y_train }, index = NewYorkdf_new.index[:17544])
train_results
# Out:
#                      Train prediction  Actual
# DateTime
# 2019-01-01 00:00:00          0.000000       0
# 2019-01-01 01:00:00          0.000000       0
# 2019-01-01 02:00:00          0.000000       0
# 2019-01-01 03:00:00          0.000000       0
# 2019-01-01 04:00:00          0.000000       0
# ...                               ...     ...
# 2020-12-31 19:00:00        124.938331     138
# 2020-12-31 20:00:00         88.029093      58
# 2020-12-31 21:00:00         23.664991      18
# 2020-12-31 22:00:00          0.000000       0
# 2020-12-31 23:00:00          0.000000       0
#
# [17544 rows x 2 columns]

# %%
plt.plot(train_results['Train prediction'][300:500], label = 'Predicted')
plt.plot(train_results['Actual'][300:500], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Random Forest: Training vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Comparision between Actual and Test predictions - Random Forest

# %%
Y_test.index = y[len(Y_train):].index
RF_results= pd.DataFrame(data = {'Test prediction':y_pred,'Actual':Y_test }, index =y[len(Y_train):].index)
RF_results
# Out:
#                      Test prediction  Actual
# DateTime
# 2021-01-01 00:00:00         0.000000       0
# 2021-01-01 01:00:00         0.000000       0
# 2021-01-01 02:00:00         0.000000       0
# 2021-01-01 03:00:00         0.000000       0
# 2021-01-01 04:00:00         0.000000       0
# ...                              ...     ...
# 2021-12-31 19:00:00        86.314767      39
# 2021-12-31 20:00:00        48.027006      28
# 2021-12-31 21:00:00        20.302877      21
# 2021-12-31 22:00:00         0.000000       0
# 2021-12-31 23:00:00         0.000000       0
#
# [8760 rows x 2 columns]

# %%
plt.plot(RF_results['Test prediction'][400:600], label = 'Predicted')
plt.plot(RF_results['Actual'][400:600], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Random Forest: Test vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Training and Testing scores of Random Forest

# %%
from sklearn.metrics import r2_score
print('Training score:', r2_score(Y_train, train_results['Train prediction'] ))
print('Testing score:', r2_score(RF_results['Actual'], RF_results['Test prediction']))
RF_results.corr()['Test prediction']
# Out:
# Training score: 0.9845963694572181
# Testing score: 0.9505973450441452
# Test prediction    1.000000
# Actual             0.975051
# Name: Test prediction, dtype: float64

# %% [markdown]
# ## Scenario 2

# %% [markdown]
# ##### Winter: 12 ,1 ,2
# ##### Spring: 3,4,5
# ##### Summer: 6,7,8
# ##### Fall : 9,10,11

# %%
Fall_RF = RF_results['2021-9-1 01:00:00': '2021-11-30 23:00:00']
Spring_RF =RF_results['2021-3-1 01:00:00': '2021-5-31 23:00:00']
Summer_RF = RF_results['2021-6-1 01:00:00': '2021-8-31 23:00:00']
W = RF_results['2021-1-1 01:00:00': '2021-2-28 23:00:00']
W.values.tolist()
Winter_RF =pd.concat([W, RF_results.loc['2020-12-1 01:00:00': '2020-12-31 23:00:00']])

Winter_RF
# Out:
#                      Test prediction  Actual
# DateTime
# 2021-01-01 01:00:00         0.000000       0
# 2021-01-01 02:00:00         0.000000       0
# 2021-01-01 03:00:00         0.000000       0
# 2021-01-01 04:00:00         0.000000       0
# 2021-01-01 05:00:00         0.000000       0
# ...                              ...     ...
# 2021-02-28 19:00:00        90.423565      69
# 2021-02-28 20:00:00        54.586191      32
# 2021-02-28 21:00:00        43.286796      50
# 2021-02-28 22:00:00        26.297614      33
# 2021-02-28 23:00:00         0.000000       0
#
# [1415 rows x 2 columns]

# %% [markdown]
# #### Winter

# %%
plt.plot(Winter_RF['Test prediction'][400:600],label = 'predicted')
plt.plot(Winter_RF['Actual'][400:600], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Rainforest model: Testing Prediction vs Actuals in Winter')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Summer

# %%
plt.plot(Summer_RF['Test prediction'][100:300],label = 'predicted')
plt.plot(Summer_RF['Actual'][100:300], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Rainforest model: Testing Prediction vs Actuals in Summer')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Spring

# %%
plt.plot(Spring_RF['Test prediction'][100:300],label = 'predicted')
plt.plot(Spring_RF['Actual'][100:300], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Rainforest model: Testing Prediction vs Actuals in Spring')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Fall

# %%
plt.plot(Fall_RF['Test prediction'][100:300],label = 'predicted')
plt.plot(Fall_RF['Actual'][100:300], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Rainforest model: Testing Prediction vs Actuals in Fall')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# ## Compare all the three methods for Senario 2

# %%
### LSTM
import pickle
# %store -r Fall_LSTM
# %store -r Spring_LSTM
# %store -r Summer_LSTM
# %store -r Winter_LSTM

# %%
### Transformer
# %store -r Fall_TR
# %store -r Spring_TR
# %store -r Summer_TR
# %store -r Winter_TR

# %% [markdown]
# ### Winter

# %%
plt.plot(Winter_LSTM['Test prediction'][200:300],label = 'LSTM Model')
plt.plot(Winter_RF['Test prediction'][200:300],label = 'Random Forest Model')
plt.plot(Winter_TR['Test prediction'][200:300],label = 'Transformer Model')
plt.plot(Winter_RF['Actual'][200:300], label = 'Actual',color='black')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Winter: Testing Prediction vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend(bbox_to_anchor =(1, 1), ncol = 1)

# %% [markdown]
# ### Spring

# %%
plt.plot(Spring_LSTM['Test prediction'][200:300],label = 'LSTM Model')
plt.plot(Spring_RF['Test prediction'][200:300],label = 'Random Forest Model')
plt.plot(Spring_TR['Test prediction'][200:300],label = 'Transformer Model')
plt.plot(Spring_RF['Actual'][200:300], label = 'Actual',color='black')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Spring: Testing Prediction vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend(bbox_to_anchor =(1, 1), ncol = 1)

# %% [markdown]
# ### Fall

# %%
plt.plot(Fall_LSTM['Test prediction'][200:300],label = 'LSTM Model')
plt.plot(Fall_RF['Test prediction'][200:300],label = 'Random Forest Model')
plt.plot(Fall_TR['Test prediction'][200:300],label = 'Transformer Model')
plt.plot(Fall_RF['Actual'][200:300], label = 'Actual',color='black')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Fall: Testing Prediction vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend(bbox_to_anchor =(1, 1), ncol = 1)

# %% [markdown]
# ### Summer

# %%
plt.plot(Summer_LSTM['Test prediction'][200:300],label = 'LSTM Model')
plt.plot(Summer_RF['Test prediction'][200:300],label = 'Random Forest Model')
plt.plot(Summer_TR['Test prediction'][200:300],label = 'Transformer Model')
plt.plot(Summer_RF['Actual'][200:300], label = 'Actual',color='black')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Summer: Testing Prediction vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend(bbox_to_anchor =(1, 1), ncol = 1)
