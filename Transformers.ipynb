# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv("New York Solar1.csv")
df
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 0      2019      1    1     0       0    0             0           8
# 1      2019      1    1     1       0    0             0           7
# 2      2019      1    1     2       0    0             0           6
# 3      2019      1    1     3       0    0             0           6
# 4      2019      1    1     4       0    0             0           6
# ...     ...    ...  ...   ...     ...  ...           ...         ...
# 26299  2021     12   31    19       0   39           318           8
# 26300  2021     12   31    20       0   28           197           8
# 26301  2021     12   31    21       0   21            62           7
# 26302  2021     12   31    22       0    0             0           7
# 26303  2021     12   31    23       0    0             0           7
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  GHI_DAY_AHEAD
# 0             4.6              95.61          5.9      1017              0
# 1             4.9              95.70          6.4      1015              0
# 2             4.3              96.75          6.7      1013              0
# 3             4.1              97.53          7.1      1011              0
# 4             3.9              98.02          7.7      1008              0
# ...           ...                ...          ...       ...            ...
# 26299         1.6              92.28         10.4      1012            207
# 26300         1.4              95.16         10.0      1012             96
# 26301         1.3              97.93          9.3      1012             38
# 26302         1.3              99.08          9.0      1012              0
# 26303         1.2              99.45          8.9      1012              0
#
# [26304 rows x 13 columns]

# %%
NewYork_df = pd.read_csv("New York Solar1.csv")
NewYork_df
# Out:
#        Year  Month  Day  Hour  Minute  GHI  Clearsky GHI  Cloud Type  \
# 0      2019      1    1     0       0    0             0           8
# 1      2019      1    1     1       0    0             0           7
# 2      2019      1    1     2       0    0             0           6
# 3      2019      1    1     3       0    0             0           6
# 4      2019      1    1     4       0    0             0           6
# ...     ...    ...  ...   ...     ...  ...           ...         ...
# 26299  2021     12   31    19       0   39           318           8
# 26300  2021     12   31    20       0   28           197           8
# 26301  2021     12   31    21       0   21            62           7
# 26302  2021     12   31    22       0    0             0           7
# 26303  2021     12   31    23       0    0             0           7
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  GHI_DAY_AHEAD
# 0             4.6              95.61          5.9      1017              0
# 1             4.9              95.70          6.4      1015              0
# 2             4.3              96.75          6.7      1013              0
# 3             4.1              97.53          7.1      1011              0
# 4             3.9              98.02          7.7      1008              0
# ...           ...                ...          ...       ...            ...
# 26299         1.6              92.28         10.4      1012            207
# 26300         1.4              95.16         10.0      1012             96
# 26301         1.3              97.93          9.3      1012             38
# 26302         1.3              99.08          9.0      1012              0
# 26303         1.2              99.45          8.9      1012              0
#
# [26304 rows x 13 columns]

# %%
NewYork_df_new = NewYork_df.copy()

NewYork_df_new['DateTime'] = NewYork_df[['Year', 'Month', 'Day', 'Hour']].apply(lambda s : datetime.datetime(*s),axis = 1)
NewYork_df_new =NewYork_df_new.drop(columns = ['Year','Minute'])
NewYork_df_new['DateTime'] = pd.to_datetime(NewYork_df_new['DateTime']) 
NewYork_df_new.set_index(['DateTime'], drop=True, inplace=True)
NewYork_df_new
# Out:
#                      Month  Day  Hour  GHI  Clearsky GHI  Cloud Type  \
# DateTime
# 2019-01-01 00:00:00      1    1     0    0             0           8
# 2019-01-01 01:00:00      1    1     1    0             0           7
# 2019-01-01 02:00:00      1    1     2    0             0           6
# 2019-01-01 03:00:00      1    1     3    0             0           6
# 2019-01-01 04:00:00      1    1     4    0             0           6
# ...                    ...  ...   ...  ...           ...         ...
# 2021-12-31 19:00:00     12   31    19   39           318           8
# 2021-12-31 20:00:00     12   31    20   28           197           8
# 2021-12-31 21:00:00     12   31    21   21            62           7
# 2021-12-31 22:00:00     12   31    22    0             0           7
# 2021-12-31 23:00:00     12   31    23    0             0           7
#
#                      Wind Speed  Relative Humidity  Temperature  Pressure  \
# DateTime
# 2019-01-01 00:00:00         4.6              95.61          5.9      1017
# 2019-01-01 01:00:00         4.9              95.70          6.4      1015
# 2019-01-01 02:00:00         4.3              96.75          6.7      1013
# 2019-01-01 03:00:00         4.1              97.53          7.1      1011
# 2019-01-01 04:00:00         3.9              98.02          7.7      1008
# ...                         ...                ...          ...       ...
# 2021-12-31 19:00:00         1.6              92.28         10.4      1012
# 2021-12-31 20:00:00         1.4              95.16         10.0      1012
# 2021-12-31 21:00:00         1.3              97.93          9.3      1012
# 2021-12-31 22:00:00         1.3              99.08          9.0      1012
# 2021-12-31 23:00:00         1.2              99.45          8.9      1012
#
#                      GHI_DAY_AHEAD
# DateTime
# 2019-01-01 00:00:00              0
# 2019-01-01 01:00:00              0
# 2019-01-01 02:00:00              0
# 2019-01-01 03:00:00              0
# 2019-01-01 04:00:00              0
# ...                            ...
# 2021-12-31 19:00:00            207
# 2021-12-31 20:00:00             96
# 2021-12-31 21:00:00             38
# 2021-12-31 22:00:00              0
# 2021-12-31 23:00:00              0
#
# [26304 rows x 11 columns]

# %%
GHI = NewYork_df_new['GHI']
GHI.plot()
plt.title('GHI in  New York from 2020-2021')
plt.ylabel('GHI ($w/m^2$)')
# Out:
# Text(0, 0.5, 'GHI ($w/m^2$)')

# %%
def df_to_X_y_24(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(0, df.shape[0]-window_size-24):
        row = [[a] for a in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size+24,3]
        y.append(label)
    return np.array(X), np.array(y)

# %%
window_size = 24
X,y = df_to_X_y_24(NewYork_df_new, 24)
m,n = X.shape[::3]
X = np.rollaxis(X,3,1).reshape(m,-1,n)
X
# Out:
# array([[[1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         ...,
#         [1.007e+03, 1.008e+03, 1.009e+03, ..., 1.018e+03, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [4.000e+01, 1.250e+02, 2.500e+02, ..., 4.200e+01, 0.000e+00,
#          0.000e+00]],
#
#        [[1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         ...,
#         [1.008e+03, 1.009e+03, 1.010e+03, ..., 1.019e+03, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          4.000e+01],
#         [1.250e+02, 2.500e+02, 3.180e+02, ..., 0.000e+00, 0.000e+00,
#          0.000e+00]],
#
#        [[1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#          1.000e+00],
#         ...,
#         [1.009e+03, 1.010e+03, 1.012e+03, ..., 1.019e+03, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 4.000e+01,
#          1.250e+02],
#         [2.500e+02, 3.180e+02, 3.290e+02, ..., 0.000e+00, 0.000e+00,
#          0.000e+00]],
#
#        ...,
#
#        [[1.200e+01, 1.200e+01, 1.200e+01, ..., 1.200e+01, 1.200e+01,
#          1.200e+01],
#         [1.200e+01, 1.200e+01, 1.200e+01, ..., 1.200e+01, 1.200e+01,
#          1.200e+01],
#         [1.200e+01, 1.200e+01, 2.900e+01, ..., 3.000e+01, 3.000e+01,
#          3.000e+01],
#         ...,
#         [1.013e+03, 1.013e+03, 1.013e+03, ..., 1.011e+03, 3.700e+01,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 8.600e+01, 3.900e+01,
#          2.800e+01]],
#
#        [[1.200e+01, 1.200e+01, 1.200e+01, ..., 1.200e+01, 1.200e+01,
#          1.200e+01],
#         [1.200e+01, 1.200e+01, 1.200e+01, ..., 1.200e+01, 1.200e+01,
#          1.200e+01],
#         [1.200e+01, 1.200e+01, 2.900e+01, ..., 3.000e+01, 3.000e+01,
#          3.000e+01],
#         ...,
#         [1.013e+03, 1.013e+03, 1.013e+03, ..., 1.011e+03, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 3.800e+01, ..., 3.900e+01, 2.800e+01,
#          2.100e+01]],
#
#        [[1.200e+01, 1.200e+01, 1.200e+01, ..., 1.200e+01, 1.200e+01,
#          1.200e+01],
#         [1.200e+01, 1.200e+01, 1.200e+01, ..., 1.200e+01, 1.200e+01,
#          1.200e+01],
#         [1.200e+01, 1.200e+01, 2.900e+01, ..., 3.000e+01, 3.000e+01,
#          3.000e+01],
#         ...,
#         [1.013e+03, 1.013e+03, 1.012e+03, ..., 1.012e+03, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#          0.000e+00],
#         [0.000e+00, 3.800e+01, 2.200e+01, ..., 2.800e+01, 2.100e+01,
#          0.000e+00]]])

# %%
X_train, X_test, Y_train, Y_test = X[:17544],X[17544:], y[:17544], y[17544:]
print('Shape of X_train set:',X_train.shape) 
print('Shape of Y_train set:',Y_train.shape)
print('Shape of X_test set:',X_test.shape)
print('Shape of Y_test set:',Y_test.shape)
y
# Out:
# Shape of X_train set: (17544, 24, 11)
# Shape of Y_train set: (17544,)
# Shape of X_test set: (8712, 24, 11)
# Shape of Y_test set: (8712,)
# array([ 0.,  0.,  0., ..., 21.,  0.,  0.])

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import *
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((24,10)))
model.add(Conv1D(100,kernel_size = 2))
model.add(Flatten())
model.add(Dense(10,'relu'))
model.add(Dense(1,'linear'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 23, 100)           2100
#
#  flatten_4 (Flatten)         (None, 2300)              0
#
#  dense_12 (Dense)            (None, 10)                23010
#
#  dense_13 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 25121 (98.13 KB)
# Trainable params: 25121 (98.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import layers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = X_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4)
)
#model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, \
    restore_best_weights=True)]

model.fit(
    X_train,
    Y_train,
    validation_split=0.2,
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 220/220 [==============================] - 43s 175ms/step - loss: 162629.4531 - val_loss: 39015.8477
# Epoch 2/30
# 220/220 [==============================] - 37s 170ms/step - loss: 62119.8242 - val_loss: 20574.0703
# Epoch 3/30
# 220/220 [==============================] - 38s 173ms/step - loss: 43594.5273 - val_loss: 16274.4590
# Epoch 4/30
# 220/220 [==============================] - 36s 164ms/step - loss: 34988.6172 - val_loss: 11957.2959
# Epoch 5/30
# 220/220 [==============================] - 37s 167ms/step - loss: 32034.7539 - val_loss: 10504.7148
# Epoch 6/30
# 220/220 [==============================] - 36s 164ms/step - loss: 29437.0742 - val_loss: 10118.6377
# Epoch 7/30
# 220/220 [==============================] - 37s 167ms/step - loss: 26633.3672 - val_loss: 9318.5508
# Epoch 8/30
# 220/220 [==============================] - 39s 178ms/step - loss: 24687.4199 - val_loss: 8945.3848
# Epoch 9/30
# 220/220 [==============================] - 39s 179ms/step - loss: 22051.0293 - val_loss: 8454.6172
# Epoch 10/30
# 220/220 [==============================] - 41s 185ms/step - loss: 20686.4043 - val_loss: 7833.5635
# Epoch 11/30
# 220/220 [==============================] - 39s 175ms/step - loss: 18785.1816 - val_loss: 7168.0347
# Epoch 12/30
# 220/220 [==============================] - 37s 168ms/step - loss: 17186.3105 - val_loss: 6459.8691
# Epoch 13/30
# 220/220 [==============================] - 37s 168ms/step - loss: 15596.3213 - val_loss: 5810.7793
# Epoch 14/30
# 220/220 [==============================] - 37s 168ms/step - loss: 14768.0459 - val_loss: 5518.3003
# Epoch 15/30
# 220/220 [==============================] - 37s 170ms/step - loss: 13571.9443 - val_loss: 5095.5566
# Epoch 16/30
# 220/220 [==============================] - 38s 173ms/step - loss: 12954.3330 - val_loss: 4545.4473
# Epoch 17/30
# 220/220 [==============================] - 37s 168ms/step - loss: 11844.8818 - val_loss: 4237.3350
# Epoch 18/30
# 220/220 [==============================] - 41s 188ms/step - loss: 11508.2490 - val_loss: 4096.0195
# Epoch 19/30
# 220/220 [==============================] - 39s 178ms/step - loss: 10853.8213 - val_loss: 3878.0596
# Epoch 20/30
# 220/220 [==============================] - 36s 162ms/step - loss: 10615.9170 - val_loss: 3779.8979
# Epoch 21/30
# 220/220 [==============================] - 36s 163ms/step - loss: 10274.6709 - val_loss: 3750.1501
# Epoch 22/30
# 220/220 [==============================] - 38s 173ms/step - loss: 9650.5156 - val_loss: 3722.0837
# Epoch 23/30
# 220/220 [==============================] - 42s 193ms/step - loss: 9647.7959 - val_loss: 3509.0303
# Epoch 24/30
# 220/220 [==============================] - 38s 172ms/step - loss: 9397.9062 - val_loss: 3597.8052
# Epoch 25/30
# 220/220 [==============================] - 36s 163ms/step - loss: 9312.6221 - val_loss: 3305.7661
# Epoch 26/30
# 220/220 [==============================] - 37s 169ms/step - loss: 9295.6777 - val_loss: 3583.3708
# Epoch 27/30
# 220/220 [==============================] - 41s 185ms/step - loss: 8974.5479 - val_loss: 3355.5156
# Epoch 28/30
# 220/220 [==============================] - 39s 175ms/step - loss: 8782.2715 - val_loss: 3370.9622
# Epoch 29/30
# 220/220 [==============================] - 40s 181ms/step - loss: 8806.4248 - val_loss: 3311.9250
# Epoch 30/30
# 220/220 [==============================] - 40s 181ms/step - loss: 8406.8770 - val_loss: 3228.4731

# %%
model.evaluate(X_test, Y_test, verbose=1)
# Out:
# 273/273 [==============================] - 6s 24ms/step - loss: 4680.5176
# 4680.517578125

# %%
train_predictions = model.predict(X_train).flatten()
train_results = pd.DataFrame(data = {'Train prediction':train_predictions,'Actual':Y_train }, index =NewYork_df_new.index[:17544]) 
plt.plot(train_results['Train prediction'][300:500], label = 'Predicted')
plt.plot(train_results['Actual'][300:500], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('CNN 1D: Training vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend()
# Out:
# 549/549 [==============================] - 13s 24ms/step

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data = {'Test prediction':test_predictions,'Actual':Y_test },index = NewYork_df_new.index[17544:26256])
test_results
# Out:
# 273/273 [==============================] - 6s 23ms/step
#                      Test prediction  Actual
# DateTime
# 2021-01-01 00:00:00        -6.538965     0.0
# 2021-01-01 01:00:00         1.586450     0.0
# 2021-01-01 02:00:00        -6.587594     0.0
# 2021-01-01 03:00:00         1.076477     0.0
# 2021-01-01 04:00:00         3.048814     0.0
# ...                              ...     ...
# 2021-12-29 19:00:00       107.864624    39.0
# 2021-12-29 20:00:00        83.844757    28.0
# 2021-12-29 21:00:00        19.703424    21.0
# 2021-12-29 22:00:00       -12.749349     0.0
# 2021-12-29 23:00:00       -16.705437     0.0
#
# [8712 rows x 2 columns]

# %%
plt.plot(test_results['Test prediction'][400:600],label = 'predicted')
plt.plot(test_results['Actual'][400:600], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Tranformer: Testing Prediction vs Actuals')
_=plt.xticks(rotation = 90)
plt.legend()

# %%
from sklearn.metrics import r2_score
print('Training score:', r2_score(Y_train, train_results['Train prediction'] ))
print('Testing score:', r2_score(test_results['Actual'], test_results['Test prediction']))
test_results.corr()['Test prediction']
# Out:
# Training score: 0.9141114059137626
# Testing score: 0.9216311072640907
# Test prediction    1.000000
# Actual             0.960309
# Name: Test prediction, dtype: float64

# %% [markdown]
# ## Scenario 2

# %% [markdown]
# ##### Winter: 12 ,1 ,2
# ##### Spring: 3,4,5
# ##### Summer: 6,7,8
# ##### Fall : 9,10,11

# %%
Fall_TR = test_results['2021-9-1 01:00:00': '2021-11-30 23:00:00']
Spring_TR =test_results['2021-3-1 01:00:00': '2021-5-31 23:00:00']
Summer_TR = test_results['2021-6-1 01:00:00': '2021-8-31 23:00:00']
W = test_results['2021-1-1 01:00:00': '2021-2-28 23:00:00']
print(W)
W.values.tolist()
Winter_TR = pd.concat([W, test_results.loc['2021-12-1 01:00:00': '2021-12-31 23:00:00']])
# Out:
#                      Test prediction  Actual
# DateTime
# 2021-01-01 01:00:00         1.586450     0.0
# 2021-01-01 02:00:00        -6.587594     0.0
# 2021-01-01 03:00:00         1.076477     0.0
# 2021-01-01 04:00:00         3.048814     0.0
# 2021-01-01 05:00:00        -7.297921     0.0
# ...                              ...     ...
# 2021-02-28 19:00:00       518.487854   615.0
# 2021-02-28 20:00:00       467.366638   474.0
# 2021-02-28 21:00:00       308.117706   286.0
# 2021-02-28 22:00:00       141.395279   121.0
# 2021-02-28 23:00:00        46.339165     0.0
#
# [1415 rows x 2 columns]

# %%
# %store Fall_TR
# %store Spring_TR
# %store Summer_TR
# %store Winter_TR
# Out:
# Stored 'Fall_TR' (DataFrame)
# Stored 'Spring_TR' (DataFrame)
# Stored 'Summer_TR' (DataFrame)
# Stored 'Winter_TR' (DataFrame)

# %% [markdown]
# #### Winter

# %%
plt.plot(Winter_TR['Test prediction'][400:600],label = 'predicted')
plt.plot(Winter_TR['Actual'][400:600], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Transformer model: Testing Prediction vs Actuals in Winter')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Summer

# %%
plt.plot(Summer_TR['Test prediction'][100:300],label = 'predicted')
plt.plot(Summer_TR['Actual'][100:300], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Transformer model: Testing Prediction vs Actuals in Summer')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Spring

# %%
plt.plot(Spring_TR['Test prediction'][100:300],label = 'predicted')
plt.plot(Spring_TR['Actual'][100:300], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Transformer model: Testing Prediction vs Actuals in Spring')
_=plt.xticks(rotation = 90)
plt.legend()

# %% [markdown]
# #### Fall

# %%
plt.plot(Fall_TR['Test prediction'][100:300],label = 'predicted')
plt.plot(Fall_TR['Actual'][100:300], label = 'Actual')
plt.xlabel('Date')
plt.ylabel('GHI ($w/m^2$)')
plt.title('Transformer model: Testing Prediction vs Actuals in Fall')
_=plt.xticks(rotation = 90)
plt.legend()
